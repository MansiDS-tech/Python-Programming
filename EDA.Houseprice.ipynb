# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Datasets/innercity.csv")
df
# Out:
#               cid        sold date   price  bed room  bathroom  home area  \
# 0      3034200666  20141107T000000  808100         4      3.25       3020
# 1      8731981640  20141204T000000  277500         4      2.50       2550
# 2      5104530220  20150420T000000  404000         3      2.50       2370
# 3      6145600285  20140529T000000  300000         2      1.00        820
# 4      8924100111  20150424T000000  699000         2      1.50       1400
# ...           ...              ...     ...       ...       ...        ...
# 21608  5137800030  20140701T000000  300000         4      2.50       2303
# 21609  8562890910  20140619T000000  320000         4      2.50       3490
# 21610  1442880160  20140627T000000  483453         4      2.75       2790
# 21611   622100130  20140917T000000  365000         2      2.00       1440
# 21612  6413600276  20150324T000000  354950         3      1.00        970
#
#        lot area  tot floors  coast  sight  ...  basement area  yr_built  \
# ...

# %%
df.head()
# Out:
#           cid        sold date   price  bed room  bathroom  home area  \
# 0  3034200666  20141107T000000  808100         4      3.25       3020
# 1  8731981640  20141204T000000  277500         4      2.50       2550
# 2  5104530220  20150420T000000  404000         3      2.50       2370
# 3  6145600285  20140529T000000  300000         2      1.00        820
# 4  8924100111  20150424T000000  699000         2      1.50       1400
#
#    lot area  tot floors  coast  sight  ...  basement area  yr_built  \
# 0     13457         1.0      0      0  ...              0      1956
# 1      7500         1.0      0      0  ...            800      1976
# 2      4324         2.0      0      0  ...              0      2006
# 3      3844         1.0      0      0  ...              0      1916
# 4      4050         1.0      0      0  ...              0      1954
#
#    yr_renovated  zipcode      lat     long  living_measure15  lot_measure15  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cid               21613 non-null  int64
#  1   sold date         21613 non-null  object
#  2   price             21613 non-null  int64
#  3   bed room          21613 non-null  int64
#  4   bathroom          21613 non-null  float64
#  5   home area         21613 non-null  int64
#  6   lot area          21613 non-null  int64
#  7   tot floors        21613 non-null  float64
#  8   coast             21613 non-null  int64
#  9   sight             21613 non-null  int64
#  10  condition         21613 non-null  int64
#  11  quality           21613 non-null  int64
#  12  ceil area         21613 non-null  int64
#  13  basement area     21613 non-null  int64
#  14  yr_built          21613 non-null  int64
#  15  yr_renovated      21613 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['cid', 'sold date', 'price', 'bed room', 'bathroom', 'home area',
#        'lot area', 'tot floors', 'coast', 'sight', 'condition', 'quality',
#        'ceil area', 'basement area', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'living_measure15', 'lot_measure15', 'furnished',
#        'total_area'],
#       dtype='object')

# %%
df.describe().transpose()
# Out:
#                     count          mean           std           min  \
# cid               21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price             21613.0  5.401822e+05  3.673622e+05  7.500000e+04
# bed room          21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathroom          21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# home area         21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# lot area          21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# tot floors        21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# coast             21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# sight             21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition         21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# quality           21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# ceil area         21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# basement area     21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %%
df.shape
# Out:
# (21613, 23)

# %%
df.tail()
# Out:
#               cid        sold date   price  bed room  bathroom  home area  \
# 21608  5137800030  20140701T000000  300000         4      2.50       2303
# 21609  8562890910  20140619T000000  320000         4      2.50       3490
# 21610  1442880160  20140627T000000  483453         4      2.75       2790
# 21611   622100130  20140917T000000  365000         2      2.00       1440
# 21612  6413600276  20150324T000000  354950         3      1.00        970
#
#        lot area  tot floors  coast  sight  ...  basement area  yr_built  \
# 21608      3826         2.0      0      0  ...              0      2006
# 21609      5000         2.0      0      0  ...              0      2003
# 21610      5527         2.0      0      0  ...              0      2014
# 21611     15000         1.0      0      0  ...              0      1985
# 21612      5922         1.5      0      0  ...              0      1949
#
#        yr_renovated  zipcode      lat     long  living_measure15  \
# ...

# %%
df.nunique()
# Out:
# cid                 21436
# sold date             372
# price                3625
# bed room               13
# bathroom               30
# home area            1038
# lot area             9782
# tot floors              6
# coast                   2
# sight                   5
# condition               5
# quality                12
# ceil area             946
# basement area         306
# yr_built              116
# yr_renovated           70
# zipcode                70
# lat                  5034
# long                  752
# living_measure15      777
# lot_measure15        8689
# furnished               2
# total_area          11163
# dtype: int64

# %%
df["furnished"].value_counts()
# Out:
# furnished
# 0    17362
# 1     4251
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# cid                 0
# sold date           0
# price               0
# bed room            0
# bathroom            0
# home area           0
# lot area            0
# tot floors          0
# coast               0
# sight               0
# condition           0
# quality             0
# ceil area           0
# basement area       0
# yr_built            0
# yr_renovated        0
# zipcode             0
# lat                 0
# long                0
# living_measure15    0
# lot_measure15       0
# furnished           0
# total_area          0
# dtype: int64

# %%
df.duplicated("furnished").sum()
# Out:
# np.int64(21611)

# %%
#Matplotlib Bars
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "red")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset("df")
sns.scatterplot(data=tips, x='cid' ,y='home area')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-11-4195480018.py in <cell line: 0>()
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 tips = sns.load_dataset("df")
#       4 sns.scatterplot(data=tips, x='cid' ,y='home area')
#       5 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     571         if not os.path.exists(cache_path):
#     572             if name not in get_dataset_names():
# --> 573                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     574             urlretrieve(url, cache_path)
#     575         full_path = cache_path
#
# ValueError: 'df' is not one of the example datasets.

# %%
import pandas as pd
my_data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Datasets/innercity.csv")
print(my_data.head())
import seaborn as sns
sns.scatterplot(data=my_data, x = "cid", y="home area")
# Out:
#           cid        sold date   price  bed room  bathroom  home area  \
# 0  3034200666  20141107T000000  808100         4      3.25       3020
# 1  8731981640  20141204T000000  277500         4      2.50       2550
# 2  5104530220  20150420T000000  404000         3      2.50       2370
# 3  6145600285  20140529T000000  300000         2      1.00        820
# 4  8924100111  20150424T000000  699000         2      1.50       1400
#
#    lot area  tot floors  coast  sight  ...  basement area  yr_built  \
# 0     13457         1.0      0      0  ...              0      1956
# 1      7500         1.0      0      0  ...            800      1976
# 2      4324         2.0      0      0  ...              0      2006
# 3      3844         1.0      0      0  ...              0      1916
# 4      4050         1.0      0      0  ...              0      1954
#
#    yr_renovated  zipcode      lat     long  living_measure15  lot_measure15  \
# ...

# %%
import pandas as pd
my_data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Datasets/innercity.csv")
print(my_data.head())
import seaborn as sns
sns.lineplot(data=my_data, x="cid", y="home area")
# Out:
#           cid        sold date   price  bed room  bathroom  home area  \
# 0  3034200666  20141107T000000  808100         4      3.25       3020
# 1  8731981640  20141204T000000  277500         4      2.50       2550
# 2  5104530220  20150420T000000  404000         3      2.50       2370
# 3  6145600285  20140529T000000  300000         2      1.00        820
# 4  8924100111  20150424T000000  699000         2      1.50       1400
#
#    lot area  tot floors  coast  sight  ...  basement area  yr_built  \
# 0     13457         1.0      0      0  ...              0      1956
# 1      7500         1.0      0      0  ...            800      1976
# 2      4324         2.0      0      0  ...              0      2006
# 3      3844         1.0      0      0  ...              0      1916
# 4      4050         1.0      0      0  ...              0      1954
#
#    yr_renovated  zipcode      lat     long  living_measure15  lot_measure15  \
# ...

# %%
import pandas as pd
my_data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Datasets/innercity.csv")
print(my_data.head())
import seaborn as sns
sns.lineplot(data=my_data, x="price", y="total_area")
# Out:
#           cid        sold date   price  bed room  bathroom  home area  \
# 0  3034200666  20141107T000000  808100         4      3.25       3020
# 1  8731981640  20141204T000000  277500         4      2.50       2550
# 2  5104530220  20150420T000000  404000         3      2.50       2370
# 3  6145600285  20140529T000000  300000         2      1.00        820
# 4  8924100111  20150424T000000  699000         2      1.50       1400
#
#    lot area  tot floors  coast  sight  ...  basement area  yr_built  \
# 0     13457         1.0      0      0  ...              0      1956
# 1      7500         1.0      0      0  ...            800      1976
# 2      4324         2.0      0      0  ...              0      2006
# 3      3844         1.0      0      0  ...              0      1916
# 4      4050         1.0      0      0  ...              0      1954
#
#    yr_renovated  zipcode      lat     long  living_measure15  lot_measure15  \
# ...

# %%
import pandas as pd
my_data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Datasets/innercity.csv")
print(my_data.head())
import seaborn as sns
sns.histplot(data=my_data, x="tot floors")
# Out:
#           cid        sold date   price  bed room  bathroom  home area  \
# 0  3034200666  20141107T000000  808100         4      3.25       3020
# 1  8731981640  20141204T000000  277500         4      2.50       2550
# 2  5104530220  20150420T000000  404000         3      2.50       2370
# 3  6145600285  20140529T000000  300000         2      1.00        820
# 4  8924100111  20150424T000000  699000         2      1.50       1400
#
#    lot area  tot floors  coast  sight  ...  basement area  yr_built  \
# 0     13457         1.0      0      0  ...              0      1956
# 1      7500         1.0      0      0  ...            800      1976
# 2      4324         2.0      0      0  ...              0      2006
# 3      3844         1.0      0      0  ...              0      1916
# 4      4050         1.0      0      0  ...              0      1954
#
#    yr_renovated  zipcode      lat     long  living_measure15  lot_measure15  \
# ...

# %%
import pandas as pd
my_data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Datasets/innercity.csv")
print(my_data.head())
import seaborn as sns
sns.histplot(data=my_data, x="tot floors", binwidth=4)
# Out:
#           cid        sold date   price  bed room  bathroom  home area  \
# 0  3034200666  20141107T000000  808100         4      3.25       3020
# 1  8731981640  20141204T000000  277500         4      2.50       2550
# 2  5104530220  20150420T000000  404000         3      2.50       2370
# 3  6145600285  20140529T000000  300000         2      1.00        820
# 4  8924100111  20150424T000000  699000         2      1.50       1400
#
#    lot area  tot floors  coast  sight  ...  basement area  yr_built  \
# 0     13457         1.0      0      0  ...              0      1956
# 1      7500         1.0      0      0  ...            800      1976
# 2      4324         2.0      0      0  ...              0      2006
# 3      3844         1.0      0      0  ...              0      1916
# 4      4050         1.0      0      0  ...              0      1954
#
#    yr_renovated  zipcode      lat     long  living_measure15  lot_measure15  \
# ...

# %%
import pandas as pd
my_data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Datasets/innercity.csv")
print(my_data.head())
import seaborn as sns
sns.histplot(data=my_data, x="furnished", hue="quality")
# Out:
#           cid        sold date   price  bed room  bathroom  home area  \
# 0  3034200666  20141107T000000  808100         4      3.25       3020
# 1  8731981640  20141204T000000  277500         4      2.50       2550
# 2  5104530220  20150420T000000  404000         3      2.50       2370
# 3  6145600285  20140529T000000  300000         2      1.00        820
# 4  8924100111  20150424T000000  699000         2      1.50       1400
#
#    lot area  tot floors  coast  sight  ...  basement area  yr_built  \
# 0     13457         1.0      0      0  ...              0      1956
# 1      7500         1.0      0      0  ...            800      1976
# 2      4324         2.0      0      0  ...              0      2006
# 3      3844         1.0      0      0  ...              0      1916
# 4      4050         1.0      0      0  ...              0      1954
#
#    yr_renovated  zipcode      lat     long  living_measure15  lot_measure15  \
# ...

# %%
g3 = pd.read_csv("C:\\Users\\Mansi\\Downloads\\weight-height(1).csv")
g3
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-7-2186504144.py in <cell line: 0>()
# ----> 1 g3 = pd.read_csv("C:\\Users\\Mansi\\Downloads\\weight-height(1).csv")
#       2 g3
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
g3 = pd.read_csv("C:/Users/Mansi/Downloads/weight-height(1)kkk.csv")
print(g3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-16-13641393.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 g3 = pd.read_csv("C:/Users/Mansi/Downloads/weight-height(1)kkk.csv")
#       3 print(g3)
#
# ...

# %%
import os
file_path = r"C:\Users\Mansi\Downloads\weight-height (1).csv"
print("File exists:", os.path.exists(file_path))
# Out:
# File exists: False

# %%
import os
import glob

# Search for the file in common locations
search_locations = [
    r"C:\Users\Mansi\Downloads",
    r"C:\Users\Mansi\Desktop",
    r"C:\Users\Mansi\Documents",
    r"C:\Downloads"
]

print("Searching for CSV files...")
for location in search_locations:
    if os.path.exists(location):
        csv_files = glob.glob(os.path.join(location, "*.csv"))
        if csv_files:
            print(f"\nCSV files in {location}:")
            for file in csv_files:
                print(f"  {file}")
# Out:
# Searching for CSV files...
